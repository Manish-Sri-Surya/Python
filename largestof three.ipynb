# %%
n1=float(input())
n2=float(input())
n3=float(input())
if n1>n2:
    if n1>n3:
        print(n1)
    else:
        print(n3)
else:
    if n2>n3:
        print(n2)
    else:
        print(n3)
# Out:
#  13
#  12
#  11
# 13.0
